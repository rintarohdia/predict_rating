# %%
import pandas as pd
df1=pd.read_csv("data1.csv")
df2=pd.read_csv("data2.csv")
df3=pd.read_csv("data3.csv")
df4=pd.read_csv("data4.csv")

# %%
merged_df = pd.concat([df1, df2, df3,df4], ignore_index=True)

# %%
merged_df
# Out:
#       Number of employees Last avail. yr  \
# 0                              2100000.0
# 1                                70496.0
# 2                              1541000.0
# 3                               385691.0
# 4                                62000.0
# ...                                  ...
# 1079                              2256.0
# 1080                              5000.0
# 1081                             15018.0
# 1082                             30106.0
# 1083                             13400.0
#
#       Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 0                                                   0.0
# 1                                            60279204.0
# 2                                                   0.0
# 3                                            17046024.0
# 4                                                   0.0
# ...                                                 ...
# ...

# %%
merged_df.to_csv('data_formed1.csv', index=False)
