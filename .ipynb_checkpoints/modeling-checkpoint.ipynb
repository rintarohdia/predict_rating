# %%
import pandas as pd

# %%
df=pd.read_csv("data_formed.csv")

# %%
seed=5

# %%
print(seed)
df.sample(frac=1, random_state=seed)
# Out:
# 5
#       Number of employees Last avail. yr  \
# 634                              57500.0
# 964                              25600.0
# 212                              62260.0
# 327                                  0.0
# 1059                             14500.0
# ...                                  ...
# 1032                             39950.0
# 73                              342982.0
# 998                              48300.0
# 206                              51369.0
# 867                              21000.0
#
#       Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 634                                                 0.0
# 964                                                 0.0
# 212                                                 0.0
# 327                                           3750586.0
# 1059                                                0.0
# ...                                                 ...
# ...

# %%
y=df["Moody's Long-Term Rating"]
merged_df=df.drop("Moody's Long-Term Rating",axis=1)

# %%
learn_x=merged_df[:900].values
learn_y=y[:900].values
test_x=merged_df[900:].values
test_y=y[900:].values

# %%
test_x
# Out:
# array([[ 0.18423914, -0.41505955, -0.40990707, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.49388478, -0.26939259,  0.46269844, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.29989747, -0.08509228, -0.08438245, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.35663323, -0.41505955, -0.40990707, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.21874194, -0.41505955, -0.40990707, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.37142035, -0.41505955, -0.40990707, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
from sklearn.preprocessing import StandardScaler

# DataFrameの全体を正規化
scaler = StandardScaler()
merged_df = pd.DataFrame(scaler.fit_transform(merged_df), columns=merged_df.columns)

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(merged_df)
n_components = 500 # 削減後の次元数
pca = PCA(n_components=n_components)
pca_num = pca.fit_transform(merged_df)
pca_df=pd.DataFrame(pca_num)

# %%
pca_df
# Out:
#              0           1           2          3          4           5    \
# 0     135.427108  -10.373675   17.082003  71.327138  63.812329 -113.378232
# 1     292.557360  315.760411  113.573438 -37.020434 -12.661557   38.211126
# 2     133.829095    3.401411   13.949564  86.919341  17.694462  -55.767081
# 3     137.519544   33.790445  -25.567817 -32.501071  14.640544  -65.622452
# 4     151.535836  -29.902730   70.597311  39.443630  67.252712  -19.503618
# ...          ...         ...         ...        ...        ...         ...
# 1079  -14.744590   -1.062653    2.661440  -0.498528  -0.044882    1.082035
# 1080  -14.745310    0.263008   -0.581478  -2.036111  -1.051492    2.024582
# 1081  -12.919156    2.895984    2.275674   2.422382   1.726455    1.026422
# 1082  -16.225473    2.799657    0.432242   2.406557   0.692308    0.889014
# 1083  -19.594306    1.658977   -1.278866   0.905649   1.155960    0.154800
#
# ...

# %%
learn_x=pca_df[:900].values
learn_y=y[:900].values
test_x=pca_df[900:].values
test_y=y[900:].values

# %%
test_x
# Out:
# array([[-8.43587242e+00,  4.49056377e-01, -1.00938307e+00, ...,
#         -9.14657401e-02,  1.74088120e-02, -2.04838062e-02],
#        [-2.51151876e+00,  4.73237483e+00, -1.16910774e+00, ...,
#         -7.48792005e-02, -3.77686622e-02,  2.91117726e-02],
#        [-4.23207837e+00, -1.92487087e+00,  3.63132307e-02, ...,
#         -8.28434359e-02,  5.03495386e-02, -1.46995357e-02],
#        ...,
#        [-1.29191555e+01,  2.89598444e+00,  2.27567379e+00, ...,
#          1.05617739e-01,  1.25139675e-01,  2.40894817e-02],
#        [-1.62254730e+01,  2.79965678e+00,  4.32241750e-01, ...,
#          8.45572398e-02, -2.17722998e-02,  3.76540020e-02],
#        [-1.95943063e+01,  1.65897697e+00, -1.27886634e+00, ...,
#         -1.80970567e-03, -1.58483408e-02, -4.33446941e-02]])

# %%
test_y
# Out:
# array([14.  , 18.  , 15.  , 16.  , 14.  , 14.  , 15.  , 12.  , 13.  ,
#        14.  , 10.  , 11.  , 13.  ,  9.  , 14.  , 16.  , 12.  , 16.  ,
#        14.  , 13.  , 13.  , 11.  , 11.  , 11.  , 13.  , 12.  , 15.  ,
#         2.  , 17.25, 15.  , 12.  , 13.  , 13.  ,  9.  , 11.  , 13.  ,
#        15.  , 12.  , 12.  , 14.  , 13.  , 10.  , 14.  ,  8.  , 14.  ,
#        13.  , 13.  , 14.  , 14.  , 17.  , 11.  , 16.  , 13.  , 13.  ,
#        15.  , 12.  , 12.  , 15.  , 14.  , 14.  , 14.  , 15.  , 16.  ,
#        14.  , 13.  , 14.  , 15.  , 14.  , 16.  , 21.  , 13.  , 13.  ,
#        13.25, 12.  , 11.  , 17.  , 12.  , 15.  , 13.  ,  7.  , 12.  ,
#        12.  ,  4.  , 14.  , 12.  , 13.  , 14.  , 13.  ,  9.  ,  6.  ,
#         7.  , 16.  ,  2.  ,  7.  , 14.  , 21.  , 14.  , 15.  , 13.  ,
#        14.  , 14.  , 14.  , 13.  , 15.  , 14.  , 14.  , 15.  , 17.  ,
#        15.  , 15.  , 12.  , 18.  , 13.  ,  9.  ,  7.  , 14.  , 14.  ,
# ...

# %%
#成型官僚
#tensorflowで実験

# %%
import tensorflow as tf

# %%
from sklearn.model_selection import KFold

# ハイパーパラメータ
k = 5 # k-fold CVの分割数
num_epochs = 15 # エポック数
batch_size = 32 # バッチサイズ

# CVを行うためのインデックスを作成
kf = KFold(n_splits=k, shuffle=True, random_state=1234)

# CVのループ
mae_list = []
for train_index, val_index in kf.split(laern_x):
    # train/valデータを作成
    train_x, train_y = laern_x[train_index], laern_y[train_index]
    val_x, val_y = laern_x[val_index], laern_y[val_index]

    # モデルを構築
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(16, activation='relu', input_dim=laern_x.shape[1]),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

    # モデルを学習
    history = model.fit(train_x, train_y, epochs=num_epochs, batch_size=batch_size, validation_data=(val_x, val_y))

    # テストデータで評価
    test_loss, test_mae = model.evaluate(test_x, test_y)
    mae_list.append(test_mae)

# 結果を出力
print('Test MAE:', np.mean(mae_list))
# Out:
# Epoch 1/15
# 23/23 [==============================] - 2s 51ms/step - loss: 127.3009 - mae: 10.5918 - val_loss: 66.2638 - val_mae: 6.9383
# Epoch 2/15
# 23/23 [==============================] - 0s 5ms/step - loss: 56.7379 - mae: 6.1762 - val_loss: 53.4655 - val_mae: 6.1643
# Epoch 3/15
# 23/23 [==============================] - 0s 4ms/step - loss: 35.0782 - mae: 4.7130 - val_loss: 35.1592 - val_mae: 4.7545
# Epoch 4/15
# 23/23 [==============================] - 0s 4ms/step - loss: 22.2409 - mae: 3.6017 - val_loss: 25.3001 - val_mae: 3.9127
# Epoch 5/15
# 23/23 [==============================] - 0s 4ms/step - loss: 13.7253 - mae: 2.8065 - val_loss: 21.6111 - val_mae: 3.3608
# Epoch 6/15
# 23/23 [==============================] - 0s 4ms/step - loss: 10.0885 - mae: 2.3773 - val_loss: 19.5750 - val_mae: 3.1840
# Epoch 7/15
# 23/23 [==============================] - 0s 4ms/step - loss: 7.4695 - mae: 2.0439 - val_loss: 18.6591 - val_mae: 2.9570
# Epoch 8/15
# ...
