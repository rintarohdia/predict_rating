# %%
import pandas as pd

# %%
df=pd.read_csv("Osiris_Export_1(tlansed).csv")

# %%
df
# Out:
#      Mark                                       Company name  \
# 0       1                                       WALMART INC.
# 1       2  SAUDI ARABIAN OIL COMPANY SAUDI JOINT STOCK CO...
# 2       3                                   AMAZON.COM, INC.
# 3       4             CHINA PETROLEUM & CHEMICAL CORPORATION
# 4       5                         PETROCHINA COMPANY LIMITED
# ..    ...                                                ...
# 266   267                                           CHS INC.
# 267   268                             GREAT-WEST LIFECO INC.
# 268   269  BANDAR ABBAS OIL REFINING COMPANY PUBLIC JOINT...
# 269   270                           GOLDMAN SACHS GROUP, INC
# 270   271                               POWER FINANCIAL CORP
#
#     Country code (incorp)   GICS code Cons. code  \
# 0                      US  30101040.0         C1
# 1                      SA  10102010.0         C1
# 2                      US  25503030.0         C1
# ...

# %%
df=df.dropna(subset=["Moody's Long-Term Rating"])

# %%
df.dtypes
# Out:
# Mark                                                int64
# Company name                                       object
# Country code (incorp)                              object
# GICS code                                         float64
# Cons. code                                         object
#                                                    ...
# Dividend share capital other th USD Year - 2.4     object
# Dividend share capital other th USD Year - 3.4     object
# Dividend share capital other th USD Year - 4.4     object
# Dividend share capital other th USD Year - 5.4     object
# Moody's Long-Term Rating                           object
# Length: 3682, dtype: object

# %%
df = df.drop(labels=["Country code (incorp)",'Company name', 'Mark','GICS code',"Operating Rev./ Turnover th USD Last avail. yr","ISIN Number"], axis=1)

# %%
df
# Out:
#     Cons. code Number of employees Last avail. yr Indep. Ind.  \
# 0           C1                          2,100,000          B+
# 1           C1                             70,496           D
# 2           C1                          1,541,000          A+
# 3           C1                            385,691           D
# 5           C1                             62,000          A+
# ..         ...                                ...         ...
# 261         C1                               n.a.           D
# 262         C1                               n.a.           C
# 263         C1                            129,700          A+
# 264         C1                            129,700           D
# 265         C2                               n.a.          A+
#
#     Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 0                                                 n.a.
# 1                                           60,279,203
# ...

# %%
y=df["Moody's Long-Term Rating"]

# %%
categories=df[["Cons. code","Indep. Ind."]]

# %%
nums=df.drop(["Moody's Long-Term Rating","Cons. code","Indep. Ind."],axis=1)

# %%
import numpy as np
nums=nums.replace("n.a.",0)

# %%
nums=nums.astype("float32")
# Out:
#     Number of employees Last avail. yr  \
# 0                            2,100,000
# 1                               70,496
# 2                            1,541,000
# 3                              385,691
# 5                               62,000
# ..                                 ...
# 261                                  0
# 262                                  0
# 263                            129,700
# 264                            129,700
# 265                                  0
#
#     Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 0                                                    0
# 1                                           60,279,203
# 2                                                    0
# 3                                           17,046,025
# 5                                                    0
# ..                                                 ...
# 261                                                  0
# ...

# %%
categories=pd.get_dummies(categories)

# %%
categories=categories.astype('float32')

# %%
y
# Out:
# 0        Aa2
# 1         A1
# 2         A1
# 3         A1
# 5        Aa2
#        ...
# 261       WR
# 262       WR
# 263       B2
# 264      Ba3
# 265    (P)A2
# Name: Moody's Long-Term Rating, Length: 202, dtype: object

# %%
y.value_counts()
# Out:
# Baa1     32
# Baa2     30
# A2       24
# A3       23
# A1       23
# WR       16
# Baa3     15
# Aa2      11
# Aa3       8
# Ba3       4
# Ba2       4
# Aaa       4
# Caa2      2
# Ba1       1
# (P)A1     1
# B1        1
# Aa1       1
# B2        1
# (P)A2     1
# Name: Moody's Long-Term Rating, dtype: int64

# %%
mapping = {
    'Aaa': 21, 'Aa1': 20, 'Aa2': 19, 'Aa3': 18,
    'A1': 17, 'A2': 16, 'A3': 15,
    'Baa1': 14, 'Baa2': 13, 'Baa3': 12,
    'Ba1': 11, 'Ba2': 10, 'Ba3': 9,
    'B1': 8, 'B2': 7, 'B3': 6,
    'Caa1': 5, 'Caa2': 4, 'Caa3': 3,
    'Ca': 2, 'C': 1, 'WR': 0,
    '(P)Aaa': 21.25, '(P)Aa1': 20.25, '(P)Aa2': 19.25, '(P)Aa3': 18.25,
    '(P)A1': 17.25, '(P)A2': 16.25, '(P)A3': 15.25,
    '(P)Baa1': 14.25, '(P)Baa2': 13.25, '(P)Baa3': 12.25,
    '(P)Ba1': 11.25, '(P)Ba2': 10.25, '(P)Ba3': 9.25,
    '(P)B1': 8.25, '(P)B2': 7.25, '(P)B3': 6.25,
    '(P)Caa1': 5.25, '(P)Caa2': 4.25, '(P)Caa3': 3.25,
    '(P)Ca': 2.25, '(P)C': 1.25, '(P)WR': 0.25,
    '(M)Aaa': 20.75, '(M)Aa1': 19.75, '(M)Aa2': 18.75, '(M)Aa3': 17.75,
    '(M)A1': 16.75, '(M)A2': 15.75, '(M)A3': 14.75,
    '(M)Baa1': 13.75, '(M)Baa2': 12.75, '(M)Baa3': 11.75,
    '(M)Ba1': 10.75, '(M)Ba2': 9.75, '(M)Ba3': 8.75,
    '(M)B1': 7.75, '(M)B2': 6.75, '(M)B3': 5.75,
    '(M)Caa1': 4.75, '(M)Caa2': 3.75, '(M)Caa3': 2.75,
    '(M)Ca': 1.75, '(M)C': 0.75, '(M)WR': -0.25}

# %%
y_formed= y.map(mapping)

# %%
y_formed
# Out:
# 0      19.00
# 1      17.00
# 2      17.00
# 3      17.00
# 5      19.00
#        ...
# 261     0.00
# 262     0.00
# 263     7.00
# 264     9.00
# 265    16.25
# Name: Moody's Long-Term Rating, Length: 202, dtype: float64

# %%
merged_df = pd.concat([nums,categories,y_formed ], axis=1)

# %%
merged_df
# Out:
#     Number of employees Last avail. yr  \
# 0                            2,100,000
# 1                               70,496
# 2                            1,541,000
# 3                              385,691
# 5                               62,000
# ..                                 ...
# 261                                  0
# 262                                  0
# 263                            129,700
# 264                            129,700
# 265                                  0
#
#     Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 0                                                    0
# 1                                           60,279,203
# 2                                                    0
# 3                                           17,046,025
# 5                                                    0
# ..                                                 ...
# 261                                                  0
# ...

# %%
merged_df.dtypes
# Out:
# Number of employees Last avail. yr                                     object
# Cash & Cash Equivalents at the End of Period th USD Last avail. yr     object
# Cash & Cash Equivalents at the End of Period th USD Year - 1           object
# Cash & Cash Equivalents at the End of Period th USD Year - 2           object
# Cash & Cash Equivalents at the End of Period th USD Year - 3           object
#                                                                        ...
# Indep. Ind._C                                                           uint8
# Indep. Ind._C+                                                          uint8
# Indep. Ind._D                                                           uint8
# Indep. Ind._U                                                           uint8
# Moody's Long-Term Rating                                              float64
# Length: 3683, dtype: object

# %%
learn=merged_df[:150]
test=merged_df[150:]

# %%
laern_y=learn["Moody's Long-Term Rating"].values
laern_x=learn.drop("Moody's Long-Term Rating",axis=1).values

# %%
test_y=test["Moody's Long-Term Rating"].values
test_x=test.drop("Moody's Long-Term Rating",axis=1).values

# %%
laern_x
# Out:
#     Number of employees Last avail. yr  \
# 0                            2,100,000
# 1                               70,496
# 2                            1,541,000
# 3                              385,691
# 5                               62,000
# ..                                 ...
# 181                             58,000
# 182                             96,000
# 183                             23,500
# 185                            721,000
# 186                                  0
#
#     Cash & Cash Equivalents at the End of Period th USD Last avail. yr  \
# 0                                                    0
# 1                                           60,279,203
# 2                                                    0
# 3                                           17,046,025
# 5                                                    0
# ..                                                 ...
# 181                                                  0
# ...

# %%
#成型官僚
#tensorflowで実験

# %%
import tensorflow as tf

# %%
# モデルの構築
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_dim=laern_x.shape[1]),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# モデルのコンパイル
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# モデルの学習
history = model.fit(laern_x, laern_y, epochs=100, batch_size=32, validation_split=0.1)

# テストデータでの評価
test_loss, test_mae = model.evaluate(test_x, test_y)
print('Test MAE:', test_mae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 12
#       9 model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
#      11 # モデルの学習
# ---> 12 history = model.fit(laern_x, laern_y, epochs=100, batch_size=32, validation_split=0.1)
#      14 # テストデータでの評価
#      15 test_loss, test_mae = model.evaluate(test_x, test_y)
#
# File ~\anaconda3\envs\py-TF2.0\lib\site-packages\keras\engine\training.py:1134, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1128   self._cluster_coordinator = tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1129       self.distribute_strategy)
# ...
